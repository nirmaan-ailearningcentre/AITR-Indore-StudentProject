# %% [markdown]
# # Retail Stores Sales Dashboard
#
# **Student Name:** Devendra Vaishnav
#
# This project analyzes retail store sales data using Python libraries like Pandas and Matplotlib.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
try:
    df = pd.read_csv('Retail_Stores_Sales_Dashboard.csv')
    print('Dataset loaded successfully!')
except FileNotFoundError:
    print('CSV file not found. Please upload Retail_Stores_Sales_Dashboard.csv')
    df = pd.DataFrame()

df.head()

# %% [markdown]
# ## Data Exploration

# %%
if not df.empty:
    print(df.info())
    display(df.describe())
else:
    print('No data available for exploration.')

# %% [markdown]
# ## Data Cleaning

# %%
if not df.empty:
    print('Missing Values:')
    print(df.isnull().sum())

    # Remove duplicate rows
    df = df.drop_duplicates()
    print('\nDuplicates removed successfully!')
else:
    print('No data available for cleaning.')

# %% [markdown]
# ## Data Visualization

# %%
if not df.empty:
    df.hist(figsize=(10, 8))
    plt.tight_layout()
    plt.show()
else:
    print('No data available for visualization.')

# %% [markdown]
# ## Conclusion
#
# The Retail Stores Sales Dashboard helps in analyzing sales performance, identifying top-selling products, tracking sales trends, and understanding customer purchasing behavior.
#
# This project improves business decision-making through visual insights and reports. It also helps store managers manage inventory efficiently and plan future business strategies.
#
# Overall, the dashboard makes sales analysis faster, easier, and more accurate.
