# %%
import pandas as pd

# %%
df = pd.read_csv("Pass-Fail Data.csv")

# %%
print(df.head())
# Out:
#    student_id  attendance_pct  homework_pct  midterm_score  \
# 0           1              95            92             88
# 1           2              88            85             79
# 2           3              60            55             58
# 3           4              72            70             65
# 4           5              40            45             50
#
#    study_hours_per_week  pass
# 0                    12     1
# 1                    10     1
# 2                     4     0
# 3                     6     1
# 4                     3     0

# %%
print(df.tail())
# Out:
#     student_id  attendance_pct  homework_pct  midterm_score  \
# 95          96              89            92             94
# 96          97              79            77             75
# 97          98              55            56             58
# 98          99              91            90             88
# 99         100              52            50             53
#
#     study_hours_per_week  pass
# 95                    14     1
# 96                     8     1
# 97                     5     0
# 98                    12     1
# 99                     4     0

# %%
print(df.shape)
# Out:
# (100, 6)

# %%
print(df.columns)
# Out:
# Index(['student_id', 'attendance_pct', 'homework_pct', 'midterm_score',
#        'study_hours_per_week', 'pass'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# student_id              int64
# attendance_pct          int64
# homework_pct            int64
# midterm_score           int64
# study_hours_per_week    int64
# pass                    int64
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            100 non-null    int64
#  1   attendance_pct        100 non-null    int64
#  2   homework_pct          100 non-null    int64
#  3   midterm_score         100 non-null    int64
#  4   study_hours_per_week  100 non-null    int64
#  5   pass                  100 non-null    int64
# dtypes: int64(6)
# memory usage: 4.8 KB
# None

# %%
print(df.describe())
# Out:
#        student_id  attendance_pct  homework_pct  midterm_score  \
# count  100.000000      100.000000     100.00000     100.000000
# mean    50.500000       69.520000      69.03000      68.780000
# std     29.011492       17.651783      17.01304      14.717254
# min      1.000000       30.000000      35.00000      42.000000
# 25%     25.750000       55.000000      55.00000      56.000000
# 50%     50.500000       72.500000      70.00000      68.000000
# 75%     75.250000       85.000000      85.00000      82.000000
# max    100.000000       95.000000      96.00000      97.000000
#
#        study_hours_per_week        pass
# count             100.00000  100.000000
# mean                7.28000    0.600000
# std                 3.62115    0.492366
# min                 2.00000    0.000000
# 25%                 4.00000    0.000000
# 50%                 7.00000    1.000000
# 75%                10.00000    1.000000
# max                15.00000    1.000000

# %%
print(df.mean(numeric_only=True))
# Out:
# student_id              50.50
# attendance_pct          69.52
# homework_pct            69.03
# midterm_score           68.78
# study_hours_per_week     7.28
# pass                     0.60
# dtype: float64

# %%
print(df.max())
# Out:
# student_id              100
# attendance_pct           95
# homework_pct             96
# midterm_score            97
# study_hours_per_week     15
# pass                      1
# dtype: int64

# %%
print(df.min())
# Out:
# student_id               1
# attendance_pct          30
# homework_pct            35
# midterm_score           42
# study_hours_per_week     2
# pass                     0
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# student_id              0
# attendance_pct          0
# homework_pct            0
# midterm_score           0
# study_hours_per_week    0
# pass                    0
# dtype: int64

# %%
print(df.iloc[0])
# Out:
# student_id               1
# attendance_pct          95
# homework_pct            92
# midterm_score           88
# study_hours_per_week    12
# pass                     1
# Name: 0, dtype: int64

# %%
print(df.iloc[0:10])
# Out:
#    student_id  attendance_pct  homework_pct  midterm_score  \
# 0           1              95            92             88
# 1           2              88            85             79
# 2           3              60            55             58
# 3           4              72            70             65
# 4           5              40            45             50
# 5           6              85            90             91
# 6           7              78            80             74
# 7           8              55            60             62
# 8           9              90            88             84
# 9          10              68            65             60
#
#    study_hours_per_week  pass
# 0                    12     1
# 1                    10     1
# 2                     4     0
# 3                     6     1
# 4                     3     0
# 5                    14     1
# 6                     8     1
# 7                     5     0
# 8                    11     1
# ...

# %%
print(df.sort_values("midterm_score"))
# Out:
#     student_id  attendance_pct  homework_pct  midterm_score  \
# 10          11              30            35             42
# 70          71              34            39             44
# 40          41              33            38             45
# 82          83              38            42             46
# 52          53              36            41             47
# ..         ...             ...           ...            ...
# 14          15              92            95             93
# 65          66              88            91             93
# 95          96              89            92             94
# 44          45              93            94             95
# 74          75              94            96             97
#
#     study_hours_per_week  pass
# 10                     2     0
# 70                     2     0
# 40                     2     0
# 82                     2     0
# 52                     2     0
# ..                   ...   ...
# ...

# %%
print(df.sort_values("midterm_score", ascending=False))
# Out:
#     student_id  attendance_pct  homework_pct  midterm_score  \
# 74          75              94            96             97
# 44          45              93            94             95
# 95          96              89            92             94
# 14          15              92            95             93
# 65          66              88            91             93
# ..         ...             ...           ...            ...
# 52          53              36            41             47
# 82          83              38            42             46
# 40          41              33            38             45
# 70          71              34            39             44
# 10          11              30            35             42
#
#     study_hours_per_week  pass
# 74                    15     1
# 44                    15     1
# 95                    14     1
# 14                    15     1
# 65                    14     1
# ..                   ...   ...
# ...

# %%
print(df[df["pass"] == 1])
# Out:
#     student_id  attendance_pct  homework_pct  midterm_score  \
# 0            1              95            92             88
# 1            2              88            85             79
# 3            4              72            70             65
# 5            6              85            90             91
# 6            7              78            80             74
# 8            9              90            88             84
# 9           10              68            65             60
# 11          12              82            78             76
# 12          13              74            70             68
# 14          15              92            95             93
# 16          17              80            85             82
# 18          19              88            90             86
# 19          20              70            68             66
# 21          22              83            80             78
# 23          24              76            72             70
# ...

# %%
print(df[df["attendance_pct"] > 80])
# Out:
#     student_id  attendance_pct  homework_pct  midterm_score  \
# 0            1              95            92             88
# 1            2              88            85             79
# 5            6              85            90             91
# 8            9              90            88             84
# 11          12              82            78             76
# 14          15              92            95             93
# 18          19              88            90             86
# 21          22              83            80             78
# 24          25              90            88             85
# 27          28              86            84             80
# 30          31              91            89             87
# 31          32              84            82             79
# 35          36              87            90             92
# 38          39              89            87             83
# 41          42              81            79             77
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["midterm_score"])
plt.show()

# %%
plt.hist(df["midterm_score"])
plt.show()

# %%
df["pass"].value_counts().plot(kind="bar")
plt.show()

# %%
plt.scatter(df["attendance_pct"], df["midterm_score"])
plt.show()

# %%
df["pass"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%"
)

plt.show()
